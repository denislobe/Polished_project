# %%
import sys
from pathlib import Path
PROJECT_ROOT = Path.cwd().parent
sys.path.append(str(PROJECT_ROOT))

from src.preprocessing import *
from src.io import *
from src.plotting import *
from scripts import preprocess_01, template_matching_02
from pathlib import Path

import hyperspy.api as hs

# %matplotlib qt5

# %%
preprocess_01.Ag_preprocess()

# %%
template_matching_02.Ag_template_matching()

# %%
sim = Sim(angular_resolution=0.5, precession_angle=1.0, min_intensity=1e-5, atom_type="Ag", lattice_constant=4.09, space_group=225)

# %%
result_area_I = load_results(PROJECT_ROOT / "results" / "Ag" /  "mean_area_I_results.pkl", sim)
result_area_II = load_results(PROJECT_ROOT / "results" / "Ag" /  "mean_area_II_results.pkl", sim)

# %%
best_orientations = convert_best_match_to_orientations(result_area_II[:-1])

# %%
best_orientations.scatter()

# %%
plot_best_match_ipf(result_area_I[2], sim)

# %%
plot_orientation_map(result_area_I[2], sim)
